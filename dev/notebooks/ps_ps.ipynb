# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

# %%
basepath = '/n/holylfs05/LABS/hernquist_lab/Users/abeane/gasbar/'

# %%
ps_base = basepath + 'analysis/ps/'

# %%
ps_Nbody = np.load(ps_base + 'ps_Nbody-lvl3.npy', allow_pickle=True).item()

# %%
plt.plot(ps_Nbody['Time'], savgol_filter(ps_Nbody['PatternSpeed'], 21, 3))
plt.ylim(0, 60)
plt.xlim(0, 8)
# Out:
# (0.0, 8.0)
